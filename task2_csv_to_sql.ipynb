# %%
import pandas
import sqlalchemy
import psycopg2
import pyodbc

# %%
"""
load csv data
"""
user_interaction = pandas.read_csv("/DataEngineerTasks/dataset/user_interaction.csv")
users = pandas.read_csv("/DataEngineerTasks/dataset/users.csv")

# %%
"""
table creation commands
"""
user_interactions_command = 'CREATE TABLE user_interaction (event_id varchar(36), user_id int, event_type varchar(5), event_time timestamp);'
users_command = 'CREATE TABLE users (user_id int, age varchar(5), country varchar(2));'

# %%
"""
create database
sqlalchemy
not used
"""
# engine = sqlalchemy.create_engine('postgresql+psycopg2://maciek:dbhaslo@localhost:5432/mydatabase')
# cnx = engine.connect()

# %%
"""
create database with psycopg2
connect
"""

host = 'localhost'
port = '5432'
dbname = 'mydatabase'
username = 'maciek'
pwd = 'dbhaslo'

connection = psycopg2.connect("host='{}' port={} dbname='{}' user={} password={}".format(host, 
                                                                                         port, 
                                                                                         dbname, 
                                                                                         username, 
                                                                                         pwd))

# %%
"""
create tables
needed only once
"""

cursor = connection.cursor()
cursor.execute(user_interactions_command)
cursor.execute(users_command)

# %%
"""
user interactions dataframe to database
"""

user_interactions_dataframe = pandas.DataFrame(user_interaction)
user_interactions_dataframe.columns = ['event_id', 'user_id', 'event_type', 'event_time']
cursor = connection.cursor()

for row in user_interactions_dataframe.itertuples():
    cursor.execute('INSERT INTO {} (event_id, user_id, event_type, event_time) \
                    \nVALUES ({}, {}, {}, {})'.format(
                                                'user_interaction',
                                                row.event_id,
                                                row.user_id,
                                                row.event_type,
                                                row.event_time
                                                ))

# %%
"""
users dataframe to database
"""
users_dataframe = pandas.DataFrame(users)
users_dataframe.columns = ['user_id', 'age', 'country']
cursor = connection.cursor()

for row in users_dataframe.itertuples():
    cursor.execute('INSERT INTO {} (user_id, age, country) \
                    \nVALUES ({}, {}, {})'.format(
                                                'users',
                                                row.user_id,
                                                row.age,
                                                row.country,
                                                ))

# %%
"""
commit changes in db
"""
connection.commit()

# %%
"""
read database to check if all works
"""
query_interactions = "select * from user_interaction;"
query_users = "select * from users;"
user_interactions_dataframe = pandas.read_sql_query(query_interactions,connection)
users_dataframe = pandas.read_sql_query(query_users,connection)
user_interactions_dataframe
# Out:
#                                 event_id  user_id event_type  \
# 0   D6EDEF54-6800-4394-971A-E9A001722E73        1       EXIT
# 1   D6EDEF54-6800-4394-971A-E9A001722E73        1       EXIT
# 2   D6EDEF54-6800-4394-971A-E9A001722E73        1       EXIT
# 3   D6EDEF54-6800-4394-971A-E9A001722E73        1       EXIT
# 4   D6EDEF54-6800-4394-971A-E9A001722E73        1       EXIT
# 5   D6EDEF54-6800-4394-971A-E9A001722E73        1       EXIT
# 6   D6EDEF54-6800-4394-971A-E9A001722E73        1       EXIT
# 7   D6EDEF54-6800-4394-971A-E9A001722E73        1       EXIT
# 8   D6EDEF54-6800-4394-971A-E9A001722E73        1       EXIT
# 9   D6EDEF54-6800-4394-971A-E9A001722E73        1       EXIT
# 10  D6EDEF54-6800-4394-971A-E9A001722E73        1       EXIT
# 11  D6EDEF54-6800-4394-971A-E9A001722E73        1       EXIT
# 12  D6EDEF54-6800-4394-971A-E9A001722E73        1       EXIT
# 13  D6EDEF54-6800-4394-971A-E9A001722E73        1       EXIT
# 14  D6EDEF54-6800-4394-971A-E9A001722E73        1       EXIT
# 15  D6EDEF54-6800-4394-971A-E9A001722E73        1       EXIT
# 16  D6EDEF54-6800-4394-971A-E9A001722E73        1       EXIT
# 17  D6EDEF54-6800-4394-971A-E9A001722E73        1       EXIT
# 18  D6EDEF54-6800-4394-971A-E9A001722E73        1       EXIT
# 19  D6EDEF54-6800-4394-971A-E9A001722E73        1       EXIT
# 20  D6EDEF54-6800-4394-971A-E9A001722E73        1       EXIT
# 21  D6EDEF54-6800-4394-971A-E9A001722E73        1       EXIT
# 22  D6EDEF54-6800-4394-971A-E9A001722E73        1       EXIT
# 23  D6EDEF54-6800-4394-971A-E9A001722E73        1       EXIT
# 24  D6EDEF54-6800-4394-971A-E9A001722E73        1       EXIT
# 25  D6EDEF54-6800-4394-971A-E9A001722E73        1       EXIT
# 26  D6EDEF54-6800-4394-971A-E9A001722E73        1       EXIT
#